# %% [markdown]
# ### Numpy Exercise
# In this exercise, we will be working with a dataset with the information of baseball players. Here is the code to read the dataset and convert it into lists.

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
bbdata=pd.read_csv('https://raw.githubusercontent.com/datacamp/courses-introduction-to-python/master/datasets/baseball.csv')

height=list(bbdata['Height'])
weight=list(bbdata['Weight'])

# %%
height
# Out:
# [74,
#  74,
#  72,
#  72,
#  73,
#  69,
#  69,
#  71,
#  76,
#  71,
#  73,
#  73,
#  74,
#  74,
#  69,
#  70,
#  73,
#  75,
#  78,
#  79,
#  76,
#  74,
#  76,
#  72,
#  71,
#  75,
#  77,
#  74,
#  73,
#  74,
#  78,
#  73,
#  75,
#  73,
#  75,
#  75,
#  74,
#  69,
#  71,
#  74,
#  73,
#  73,
#  76,
#  74,
#  74,
#  70,
#  72,
#  77,
#  74,
#  70,
#  73,
#  75,
#  76,
#  76,
#  78,
#  74,
#  74,
#  76,
#  77,
#  81,
#  78,
#  75,
#  77,
#  75,
#  76,
#  74,
#  72,
#  72,
#  75,
#  73,
#  73,
#  73,
#  70,
#  70,
#  70,
#  76,
#  68,
#  71,
#  72,
#  75,
#  75,
#  75,
#  75,
#  68,
#  74,
#  78,
#  71,
#  73,
#  76,
#  74,
#  74,
#  79,
#  75,
#  73,
#  76,
#  74,
#  74,
#  73,
#  72,
#  74,
#  73,
#  74,
#  72,
#  73,
#  69,
#  72,
#  73,
#  75,
#  75,
#  73,
#  72,
#  72,
#  76,
#  74,
#  72,
#  77,
#  74,
#  77,
#  75,
#  76,
#  80,
#  74,
#  74,
#  75,
#  78,
#  73,
#  73,
#  74,
#  75,
#  76,
#  71,
#  73,
#  74,
#  76,
#  76,
#  74,
#  73,
#  74,
#  70,
#  72,
#  73,
#  73,
#  73,
#  73,
#  71,
#  74,
#  74,
#  72,
#  74,
#  71,
#  74,
#  73,
#  75,
#  75,
#  79,
#  73,
#  75,
#  76,
#  74,
#  76,
#  78,
#  74,
#  76,
#  72,
#  74,
#  76,
#  74,
#  75,
#  78,
#  75,
#  72,
#  74,
#  72,
#  74,
#  70,
#  71,
#  70,
#  75,
#  71,
#  71,
#  73,
#  72,
#  71,
#  73,
#  72,
#  75,
#  74,
#  74,
#  75,
#  73,
#  77,
#  73,
#  76,
#  75,
#  74,
#  76,
#  75,
#  73,
#  71,
#  76,
#  75,
#  72,
#  71,
#  77,
#  73,
#  74,
#  71,
#  72,
#  74,
#  75,
#  73,
#  72,
#  75,
#  75,
#  74,
#  72,
#  74,
#  71,
#  70,
#  74,
#  77,
#  77,
#  75,
#  75,
#  78,
#  75,
#  76,
#  73,
#  75,
#  75,
#  79,
#  77,
#  76,
#  71,
#  75,
#  74,
#  69,
#  71,
#  76,
#  72,
#  72,
#  70,
#  72,
#  73,
#  71,
#  72,
#  71,
#  73,
#  72,
#  73,
#  74,
#  74,
#  72,
#  75,
#  74,
#  74,
#  77,
#  75,
#  73,
#  72,
#  71,
#  74,
#  77,
#  75,
#  75,
#  75,
#  78,
#  78,
#  74,
#  76,
#  78,
#  76,
#  70,
#  72,
#  80,
#  74,
#  74,
#  71,
#  70,
#  72,
#  71,
#  74,
#  71,
#  72,
#  71,
#  74,
#  69,
#  76,
#  75,
#  75,
#  76,
#  73,
#  76,
#  73,
#  77,
#  73,
#  72,
#  72,
#  77,
#  77,
#  71,
#  74,
#  74,
#  73,
#  78,
#  75,
#  73,
#  70,
#  74,
#  72,
#  73,
#  73,
#  75,
#  75,
#  74,
#  76,
#  73,
#  74,
#  75,
#  75,
#  72,
#  73,
#  73,
#  72,
#  74,
#  78,
#  76,
#  73,
#  74,
#  75,
#  70,
#  75,
#  71,
#  72,
#  78,
#  75,
#  73,
#  73,
#  71,
#  75,
#  77,
#  72,
#  69,
#  73,
#  74,
#  72,
#  70,
#  75,
#  70,
#  72,
#  72,
#  74,
#  73,
#  74,
#  76,
#  75,
#  80,
#  72,
#  75,
#  73,
#  74,
#  74,
#  73,
#  75,
#  75,
#  71,
#  73,
#  75,
#  74,
#  74,
#  72,
#  74,
#  74,
#  74,
#  73,
#  76,
#  75,
#  72,
#  73,
#  73,
#  73,
#  72,
#  72,
#  72,
#  72,
#  71,
#  75,
#  75,
#  74,
#  73,
#  75,
#  79,
#  74,
#  76,
#  73,
#  74,
#  74,
#  72,
#  74,
#  74,
#  75,
#  78,
#  74,
#  74,
#  74,
#  77,
#  70,
#  73,
#  74,
#  73,
#  71,
#  75,
#  71,
#  72,
#  77,
#  74,
#  70,
#  77,
#  73,
#  72,
#  76,
#  71,
#  76,
#  78,
#  75,
#  73,
#  78,
#  74,
#  79,
#  75,
#  76,
#  72,
#  75,
#  75,
#  70,
#  72,
#  70,
#  74,
#  71,
#  76,
#  73,
#  76,
#  71,
#  69,
#  72,
#  72,
#  69,
#  73,
#  69,
#  73,
#  74,
#  74,
#  72,
#  71,
#  72,
#  72,
#  76,
#  76,
#  76,
#  74,
#  76,
#  75,
#  71,
#  72,
#  71,
#  73,
#  75,
#  76,
#  75,
#  71,
#  75,
#  74,
#  72,
#  73,
#  73,
#  73,
#  73,
#  76,
#  72,
#  76,
#  73,
#  73,
#  73,
#  75,
#  75,
#  77,
#  73,
#  72,
#  75,
#  70,
#  74,
#  72,
#  80,
#  71,
#  71,
#  74,
#  74,
#  73,
#  75,
#  76,
#  73,
#  77,
#  72,
#  73,
#  77,
#  76,
#  71,
#  75,
#  73,
#  74,
#  77,
#  71,
#  72,
#  73,
#  69,
#  73,
#  70,
#  74,
#  76,
#  73,
#  73,
#  75,
#  73,
#  79,
#  74,
#  73,
#  74,
#  77,
#  75,
#  74,
#  73,
#  77,
#  73,
#  77,
#  74,
#  74,
#  73,
#  77,
#  74,
#  77,
#  75,
#  77,
#  75,
#  71,
#  74,
#  70,
#  79,
#  72,
#  72,
#  70,
#  74,
#  74,
#  72,
#  73,
#  72,
#  74,
#  74,
#  76,
#  82,
#  74,
#  74,
#  70,
#  73,
#  73,
#  74,
#  77,
#  72,
#  76,
#  73,
#  73,
#  72,
#  74,
#  74,
#  71,
#  72,
#  75,
#  74,
#  74,
#  77,
#  70,
#  71,
#  73,
#  76,
#  71,
#  75,
#  74,
#  72,
#  76,
#  79,
#  76,
#  73,
#  76,
#  78,
#  75,
#  76,
#  72,
#  72,
#  73,
#  73,
#  75,
#  71,
#  76,
#  70,
#  75,
#  74,
#  75,
#  73,
#  71,
#  71,
#  72,
#  73,
#  73,
#  72,
#  69,
#  73,
#  78,
#  71,
#  73,
#  75,
#  76,
#  70,
#  74,
#  77,
#  75,
#  79,
#  72,
#  77,
#  73,
#  75,
#  75,
#  75,
#  73,
#  73,
#  76,
#  77,
#  75,
#  70,
#  71,
#  71,
#  75,
#  74,
#  69,
#  70,
#  75,
#  72,
#  75,
#  73,
#  72,
#  72,
#  72,
#  76,
#  75,
#  74,
#  69,
#  73,
#  72,
#  72,
#  75,
#  77,
#  76,
#  80,
#  77,
#  76,
#  79,
#  71,
#  75,
#  73,
#  76,
#  77,
#  73,
#  76,
#  70,
#  75,
#  73,
#  75,
#  70,
#  69,
#  71,
#  72,
#  72,
#  73,
#  70,
#  70,
#  73,
#  76,
#  75,
#  72,
#  73,
#  79,
#  71,
#  72,
#  74,
#  74,
#  74,
#  72,
#  76,
#  76,
#  72,
#  72,
#  71,
#  72,
#  72,
#  70,
#  77,
#  74,
#  72,
#  76,
#  71,
#  76,
#  71,
#  73,
#  70,
#  73,
#  73,
#  72,
#  71,
#  71,
#  71,
#  72,
#  72,
#  74,
#  74,
#  74,
#  71,
#  72,
#  75,
#  72,
#  71,
#  72,
#  72,
#  72,
#  72,
#  74,
#  74,
#  77,
#  75,
#  73,
#  75,
#  73,
#  76,
#  72,
#  77,
#  75,
#  72,
#  71,
#  71,
#  75,
#  72,
#  73,
#  73,
#  71,
#  70,
#  75,
#  71,
#  76,
#  73,
#  68,
#  71,
#  72,
#  74,
#  77,
#  72,
#  76,
#  78,
#  81,
#  72,
#  73,
#  76,
#  72,
#  72,
#  74,
#  76,
#  73,
#  76,
#  75,
#  70,
#  71,
#  74,
#  72,
#  73,
#  76,
#  76,
#  73,
#  71,
#  68,
#  71,
#  71,
#  74,
#  77,
#  69,
#  72,
#  76,
#  75,
#  76,
#  75,
#  76,
#  72,
#  74,
#  76,
#  74,
#  72,
#  75,
#  78,
#  77,
#  70,
#  72,
#  79,
#  74,
#  71,
#  68,
#  77,
#  75,
#  71,
#  72,
#  70,
#  72,
#  72,
#  73,
#  72,
#  74,
#  72,
#  72,
#  75,
#  72,
#  73,
#  74,
#  72,
#  78,
#  75,
#  72,
#  74,
#  75,
#  75,
#  76,
#  74,
#  74,
#  73,
#  74,
#  71,
#  74,
#  75,
#  76,
#  74,
#  76,
#  76,
#  73,
#  75,
#  75,
#  74,
#  68,
#  72,
#  75,
#  71,
#  70,
#  72,
#  73,
#  72,
#  75,
#  74,
#  70,
#  76,
#  71,
#  82,
#  72,
#  73,
#  74,
#  71,
#  75,
#  77,
#  72,
#  74,
#  72,
#  73,
#  78,
#  77,
#  73,
#  73,
#  73,
#  73,
#  73,
#  76,
#  75,
#  70,
#  73,
#  72,
#  73,
#  75,
#  74,
#  73,
#  73,
#  76,
#  73,
#  75,
#  70,
#  77,
#  72,
#  77,
#  74,
#  75,
#  75,
#  75,
#  75,
#  72,
#  74,
#  71,
#  76,
#  71,
#  75,
#  76,
#  83,
#  75,
#  74,
#  76,
#  72,
#  72,
#  75,
#  75,
#  72,
#  77,
#  73,
#  72,
#  70,
#  74,
#  72,
#  74,
#  72,
#  71,
#  70,
#  71,
#  76,
#  74,
#  76,
#  74,
#  74,
#  74,
#  75,
#  75,
#  71,
#  71,
#  74,
#  77,
#  71,
#  74,
#  75,
#  77,
#  76,
#  74,
#  76,
#  72,
#  71,
#  72,
#  75,
#  73,
#  68,
#  72,
#  69,
#  73,
#  73,
#  75,
#  70,
#  70,
#  74,
#  75,
#  74,
#  74,
#  73,
#  74,
#  75,
#  77,
#  73,
#  74,
#  76,
#  74,
#  75,
#  73,
#  76,
#  78,
#  75,
#  73,
#  77,
#  74,
#  72,
#  74,
#  72,
#  71,
#  73,
#  75,
#  73,
#  67,
#  67,
#  76,
#  74,
#  73,
#  70,
#  75,
#  70,
#  72,
#  77,
#  79,
#  78,
#  ...]

# %%
weight
# Out:
# [180,
#  215,
#  210,
#  210,
#  188,
#  176,
#  209,
#  200,
#  231,
#  180,
#  188,
#  180,
#  185,
#  160,
#  180,
#  185,
#  189,
#  185,
#  219,
#  230,
#  205,
#  230,
#  195,
#  180,
#  192,
#  225,
#  203,
#  195,
#  182,
#  188,
#  200,
#  180,
#  200,
#  200,
#  245,
#  240,
#  215,
#  185,
#  175,
#  199,
#  200,
#  215,
#  200,
#  205,
#  206,
#  186,
#  188,
#  220,
#  210,
#  195,
#  200,
#  200,
#  212,
#  224,
#  210,
#  205,
#  220,
#  195,
#  200,
#  260,
#  228,
#  270,
#  200,
#  210,
#  190,
#  220,
#  180,
#  205,
#  210,
#  220,
#  211,
#  200,
#  180,
#  190,
#  170,
#  230,
#  155,
#  185,
#  185,
#  200,
#  225,
#  225,
#  220,
#  160,
#  205,
#  235,
#  250,
#  210,
#  190,
#  160,
#  200,
#  205,
#  222,
#  195,
#  205,
#  220,
#  220,
#  170,
#  185,
#  195,
#  220,
#  230,
#  180,
#  220,
#  180,
#  180,
#  170,
#  210,
#  215,
#  200,
#  213,
#  180,
#  192,
#  235,
#  185,
#  235,
#  210,
#  222,
#  210,
#  230,
#  220,
#  180,
#  190,
#  200,
#  210,
#  194,
#  180,
#  190,
#  240,
#  200,
#  198,
#  200,
#  195,
#  210,
#  220,
#  190,
#  210,
#  225,
#  180,
#  185,
#  170,
#  185,
#  185,
#  180,
#  178,
#  175,
#  200,
#  204,
#  211,
#  190,
#  210,
#  190,
#  190,
#  185,
#  290,
#  175,
#  185,
#  200,
#  220,
#  170,
#  220,
#  190,
#  220,
#  205,
#  200,
#  250,
#  225,
#  215,
#  210,
#  215,
#  195,
#  200,
#  194,
#  220,
#  180,
#  180,
#  170,
#  195,
#  180,
#  170,
#  206,
#  205,
#  200,
#  225,
#  201,
#  225,
#  233,
#  180,
#  225,
#  180,
#  220,
#  180,
#  237,
#  215,
#  190,
#  235,
#  190,
#  180,
#  165,
#  195,
#  200,
#  190,
#  190,
#  185,
#  185,
#  205,
#  190,
#  205,
#  206,
#  220,
#  208,
#  170,
#  195,
#  210,
#  190,
#  211,
#  230,
#  170,
#  185,
#  185,
#  241,
#  225,
#  210,
#  175,
#  230,
#  200,
#  215,
#  198,
#  226,
#  278,
#  215,
#  230,
#  240,
#  184,
#  219,
#  170,
#  218,
#  190,
#  225,
#  220,
#  176,
#  190,
#  197,
#  204,
#  167,
#  180,
#  195,
#  220,
#  215,
#  185,
#  190,
#  205,
#  205,
#  200,
#  210,
#  215,
#  200,
#  205,
#  211,
#  190,
#  208,
#  200,
#  210,
#  232,
#  230,
#  210,
#  220,
#  210,
#  202,
#  212,
#  225,
#  170,
#  190,
#  200,
#  237,
#  220,
#  170,
#  193,
#  190,
#  150,
#  220,
#  200,
#  190,
#  185,
#  185,
#  200,
#  172,
#  220,
#  225,
#  190,
#  195,
#  219,
#  190,
#  197,
#  200,
#  195,
#  210,
#  177,
#  220,
#  235,
#  180,
#  195,
#  195,
#  190,
#  230,
#  190,
#  200,
#  190,
#  190,
#  200,
#  200,
#  184,
#  200,
#  180,
#  219,
#  187,
#  200,
#  220,
#  205,
#  190,
#  170,
#  160,
#  215,
#  175,
#  205,
#  200,
#  214,
#  200,
#  190,
#  180,
#  205,
#  220,
#  190,
#  215,
#  235,
#  191,
#  200,
#  181,
#  200,
#  210,
#  240,
#  185,
#  165,
#  190,
#  185,
#  175,
#  155,
#  210,
#  170,
#  175,
#  220,
#  210,
#  205,
#  200,
#  205,
#  195,
#  240,
#  150,
#  200,
#  215,
#  202,
#  200,
#  190,
#  205,
#  190,
#  160,
#  215,
#  185,
#  200,
#  190,
#  210,
#  185,
#  220,
#  190,
#  202,
#  205,
#  220,
#  175,
#  160,
#  190,
#  200,
#  229,
#  206,
#  220,
#  180,
#  195,
#  175,
#  188,
#  230,
#  190,
#  200,
#  190,
#  219,
#  235,
#  180,
#  180,
#  180,
#  200,
#  234,
#  185,
#  220,
#  223,
#  200,
#  210,
#  200,
#  210,
#  190,
#  177,
#  227,
#  180,
#  195,
#  199,
#  175,
#  185,
#  240,
#  210,
#  180,
#  194,
#  225,
#  180,
#  205,
#  193,
#  230,
#  230,
#  220,
#  200,
#  249,
#  190,
#  208,
#  245,
#  250,
#  160,
#  192,
#  220,
#  170,
#  197,
#  155,
#  190,
#  200,
#  220,
#  210,
#  228,
#  190,
#  160,
#  184,
#  180,
#  180,
#  200,
#  176,
#  160,
#  222,
#  211,
#  195,
#  200,
#  175,
#  206,
#  240,
#  185,
#  260,
#  185,
#  221,
#  205,
#  200,
#  170,
#  201,
#  205,
#  185,
#  205,
#  245,
#  220,
#  210,
#  220,
#  185,
#  175,
#  170,
#  180,
#  200,
#  210,
#  175,
#  220,
#  206,
#  180,
#  210,
#  195,
#  200,
#  200,
#  164,
#  180,
#  220,
#  195,
#  205,
#  170,
#  240,
#  210,
#  195,
#  200,
#  205,
#  192,
#  190,
#  170,
#  240,
#  200,
#  205,
#  175,
#  250,
#  220,
#  224,
#  210,
#  195,
#  180,
#  245,
#  175,
#  180,
#  215,
#  175,
#  180,
#  195,
#  230,
#  230,
#  205,
#  215,
#  195,
#  180,
#  205,
#  180,
#  190,
#  180,
#  190,
#  190,
#  220,
#  210,
#  255,
#  190,
#  230,
#  200,
#  205,
#  210,
#  225,
#  215,
#  220,
#  205,
#  200,
#  220,
#  197,
#  225,
#  187,
#  245,
#  185,
#  185,
#  175,
#  200,
#  180,
#  188,
#  225,
#  200,
#  210,
#  245,
#  213,
#  231,
#  165,
#  228,
#  210,
#  250,
#  191,
#  190,
#  200,
#  215,
#  254,
#  232,
#  180,
#  215,
#  220,
#  180,
#  200,
#  170,
#  195,
#  210,
#  200,
#  220,
#  165,
#  180,
#  200,
#  200,
#  170,
#  224,
#  220,
#  180,
#  198,
#  240,
#  239,
#  185,
#  210,
#  220,
#  200,
#  195,
#  220,
#  230,
#  170,
#  220,
#  230,
#  165,
#  205,
#  192,
#  210,
#  205,
#  200,
#  210,
#  185,
#  195,
#  202,
#  205,
#  195,
#  180,
#  200,
#  185,
#  240,
#  185,
#  220,
#  205,
#  205,
#  180,
#  201,
#  190,
#  208,
#  240,
#  180,
#  230,
#  195,
#  215,
#  190,
#  195,
#  215,
#  215,
#  220,
#  220,
#  230,
#  195,
#  190,
#  195,
#  209,
#  204,
#  170,
#  185,
#  205,
#  175,
#  210,
#  190,
#  180,
#  180,
#  160,
#  235,
#  200,
#  210,
#  180,
#  190,
#  197,
#  203,
#  205,
#  170,
#  200,
#  250,
#  200,
#  220,
#  200,
#  190,
#  170,
#  190,
#  220,
#  215,
#  206,
#  215,
#  185,
#  235,
#  188,
#  230,
#  195,
#  168,
#  190,
#  160,
#  200,
#  200,
#  189,
#  180,
#  190,
#  200,
#  220,
#  187,
#  240,
#  190,
#  180,
#  185,
#  210,
#  220,
#  219,
#  190,
#  193,
#  175,
#  180,
#  215,
#  210,
#  200,
#  190,
#  185,
#  220,
#  170,
#  195,
#  205,
#  195,
#  210,
#  190,
#  190,
#  180,
#  220,
#  190,
#  186,
#  185,
#  190,
#  180,
#  190,
#  170,
#  210,
#  240,
#  220,
#  180,
#  210,
#  210,
#  195,
#  160,
#  180,
#  205,
#  200,
#  185,
#  245,
#  190,
#  210,
#  200,
#  200,
#  222,
#  215,
#  240,
#  170,
#  220,
#  156,
#  190,
#  202,
#  221,
#  200,
#  190,
#  210,
#  190,
#  200,
#  165,
#  190,
#  185,
#  230,
#  208,
#  209,
#  175,
#  180,
#  200,
#  205,
#  200,
#  250,
#  210,
#  230,
#  244,
#  202,
#  240,
#  200,
#  215,
#  177,
#  210,
#  170,
#  215,
#  217,
#  198,
#  200,
#  220,
#  170,
#  200,
#  230,
#  231,
#  183,
#  192,
#  167,
#  190,
#  180,
#  180,
#  215,
#  160,
#  205,
#  223,
#  175,
#  170,
#  190,
#  240,
#  175,
#  230,
#  223,
#  196,
#  167,
#  195,
#  190,
#  250,
#  190,
#  190,
#  190,
#  170,
#  160,
#  150,
#  225,
#  220,
#  209,
#  210,
#  176,
#  260,
#  195,
#  190,
#  184,
#  180,
#  195,
#  195,
#  219,
#  225,
#  212,
#  202,
#  185,
#  200,
#  209,
#  200,
#  195,
#  228,
#  210,
#  190,
#  212,
#  190,
#  218,
#  220,
#  190,
#  235,
#  210,
#  200,
#  188,
#  210,
#  235,
#  188,
#  215,
#  216,
#  220,
#  180,
#  185,
#  200,
#  210,
#  220,
#  185,
#  231,
#  210,
#  195,
#  200,
#  205,
#  200,
#  190,
#  250,
#  185,
#  180,
#  170,
#  180,
#  208,
#  235,
#  215,
#  244,
#  220,
#  185,
#  230,
#  190,
#  200,
#  180,
#  190,
#  196,
#  180,
#  230,
#  224,
#  160,
#  178,
#  205,
#  185,
#  210,
#  180,
#  190,
#  200,
#  257,
#  190,
#  220,
#  165,
#  205,
#  200,
#  208,
#  185,
#  215,
#  170,
#  235,
#  210,
#  170,
#  180,
#  170,
#  190,
#  150,
#  230,
#  203,
#  260,
#  246,
#  186,
#  210,
#  198,
#  210,
#  215,
#  180,
#  200,
#  245,
#  200,
#  192,
#  192,
#  200,
#  192,
#  205,
#  190,
#  186,
#  170,
#  197,
#  219,
#  200,
#  220,
#  207,
#  225,
#  207,
#  212,
#  225,
#  170,
#  190,
#  210,
#  230,
#  210,
#  200,
#  238,
#  234,
#  222,
#  200,
#  190,
#  170,
#  220,
#  223,
#  210,
#  215,
#  196,
#  175,
#  175,
#  189,
#  205,
#  210,
#  180,
#  180,
#  197,
#  220,
#  228,
#  190,
#  204,
#  165,
#  216,
#  220,
#  208,
#  210,
#  215,
#  195,
#  200,
#  215,
#  229,
#  240,
#  207,
#  205,
#  208,
#  185,
#  190,
#  170,
#  208,
#  225,
#  190,
#  225,
#  185,
#  180,
#  165,
#  240,
#  220,
#  212,
#  163,
#  215,
#  175,
#  205,
#  210,
#  205,
#  208,
#  ...]

# %%
import matplotlib.pyplot as plt

plt.scatter(height,weight)

# %% [markdown]
# ### Real Work begins
# We have height and weidths as lists now, you task is to convert them into numpy arrays and then acheive the following insights.
# The units are height in inches, weight in lbs

# %%
W_Array=np.array(weight)
H_Array=np.array(height)

print(W_Array)
print(H_Array)
# Out:
# [180 215 210 ... 205 190 195]
# [74 74 72 ... 75 75 73]

# %% [markdown]
# # View the Data
# Once the data is loaded, take a look at the first few rows to get an idea of what it contains.
#
# **Task**: Use a function to display the first five rows of the DataFrame `df`.

# %%
#code 
df=bbdata[:]
df[0:5]
# Out:
#               Name Team       Position  Height  Weight    Age PosCategory
# 0    Adam_Donachie  BAL        Catcher      74     180  22.99     Catcher
# 1        Paul_Bako  BAL        Catcher      74     215  34.69     Catcher
# 2  Ramon_Hernandez  BAL        Catcher      72     210  30.78     Catcher
# 3     Kevin_Millar  BAL  First_Baseman      72     210  35.43   Infielder
# 4      Chris_Gomez  BAL  First_Baseman      73     188  35.71   Infielder

# %% [markdown]
# # Check Dataset Dimensions
# Knowing the size of the dataset can help you plan data processing steps.
#
# **Task**: Use a function to display the dimensions (rows and columns) of `df`.

# %%
# code here
df.shape
# Out:
# (1015, 7)

# %% [markdown]
# # Get Data Overview
# Understanding the data types and number of non-null entries in each column is crucial for data cleaning.
#
# **Task**: Use a function to get a summary of `df` and its columns.

# %%
# CODE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1015 non-null   object
#  1   Team         1015 non-null   object
#  2   Position     1015 non-null   object
#  3   Height       1015 non-null   int64
#  4   Weight       1015 non-null   int64
#  5   Age          1015 non-null   float64
#  6   PosCategory  1015 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 55.6+ KB

# %%
# height is available as a regular list

# Import numpy
import numpy as np

# Create a Numpy array from height: np_height
np_heigth=np.array(H_Array)

# Print out np_height
print(np_heigth)


# Create array from weight with correct units: np_weight_lbs
np_weigth_lbs=np.array(W_Array)

# print the array np_weight_lbs
print(np_weigth_lbs)
# Out:
# [74 74 72 ... 75 75 73]
# [180 215 210 ... 205 190 195]

# %% [markdown]
# * 1 meter = 39.3701 inches

# %%
# Convert np_height to meters: np_height_m

np_height_m=np_heigth/39.3701
# Print np_height_m
print(np_height_m)
# Out:
# [1.87959899 1.87959899 1.82879901 ... 1.90499897 1.90499897 1.854199  ]

# %% [markdown]
# * 1 lbs(pound) = 0.453592 kg

# %%
# Convert np_weight_lbs to kgs: np_weight_kgs
np_weigth_kgs=np_weigth_lbs*0.453592

# Print np_weight_kgs
print(np_weigth_kgs)
# Out:
# [81.64656 97.52228 95.25432 ... 92.98636 86.18248 88.45044]

# %% [markdown]
# - BMI=weight(kg)/(height (in m)**2)

# %%
# Calculate the BMI: bmi

BMI=np_weigth_kgs/np_height_m**2
# Print out bmi
print(BMI)
# Out:
# [23.11040135 27.6040905  28.48083541 ... 25.62298701 23.7481343
#  25.7268914 ]

# %% [markdown]
# Create a boolean Numpy array: the element of the array should be True if the corresponding baseball player's BMI is below 21. You can use the < operator for this. Name the array light.
# Print the array light.
# Print out a Numpy array with the BMIs of all baseball players whose BMI is below 21. Use light inside square brackets to do a selection on the bmi array.

# %%
light=(BMI<21)
np_boolean=BMI[light]

print(light)
print(np_boolean)
# Out:
# [False False False ... False False False]
# [20.54257898 20.54257898 20.69284282 20.69284282 20.34345386 20.34345386
#  20.69284282 20.15885649 19.49846816 20.69284282 20.9205445 ]

# %%
# Create baseball, a list of lists
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# Import numpy
import numpy as np

# Create a 2D Numpy array from baseball: np_baseball
np_baseball=np.array(baseball)

# Print out the type of np_baseball
print(type(np_baseball))

# Print out the shape of np_baseball
print(np_baseball.shape)
# Out:
# <class 'numpy.ndarray'>
# (4, 2)

# %%
# Create a 2D Numpy array named np_baseball from the lists of weight and height
np_baseball=np.array([height,weight])

# Print out the shape of np_baseball
print(np_baseball.shape)
# Out:
# (2, 1015)

# %% [markdown]
# - If you want to convert the units of height and weight. As a first step, create a Numpy array with two values: 0.0254, 0.453592. Name this array conversion.
# Multiply np_baseball with conversion and print out the result.

# %%
conversion = np.array([0.0254, 0.453592])
converted= np_baseball.T*conversion

print(converted.T)
# Out:
# [[ 1.8796   1.8796   1.8288  ...  1.905    1.905    1.8542 ]
#  [81.64656 97.52228 95.25432 ... 92.98636 86.18248 88.45044]]

# %% [markdown]
# ### Now it's time for some statistics

# %%
# Print out the mean of np_height
np_mean_height=np.mean(height)
print(np_mean_height)

# Print out the median of np_height
np_median_heigth=np.median(height)
print(np_median_heigth)

# Print median height. Replace 'None'if any
np_median_heigth=np.median(height)
print(np_median_heigth)

# Print out the standard deviation on height. Replace 'None' if any
np_std_height = np.std(height)
print(np_std_height)
# Out:
# 73.6896551724138
# 74.0
# 74.0
# 2.312791881046546

# %%
# Print the index of player with maximum height
print(np.argmax(height))
# Out:
# 909

# %%
#Replace all the players height greater than 6 Feet with 6 Feet

np_heigth=np.where(H_Array>72,72,np_heigth)
print(np_heigth)
# Out:
# [72 72 72 ... 72 72 72]

# %%
#Count number of players with weight greater than 75 kg..
greater_than_75 =(np_weigth_kgs> 75)
# Count the number of players
count = np.sum(greater_than_75)
print(count)
# Out:
# 981

# %%
# Sort the height, and get the sorting index as well

print(np.sort(height))
print(np.argsort(height))
# Out:
# [67 67 68 ... 82 82 83]
# [989 988 953 ... 862 558 909]

# %%
#Reshape the 2 x Number of Players array to Number of Players x 2
print(np_baseball.T)
# Out:
# [[ 74 180]
#  [ 74 215]
#  [ 72 210]
#  ...
#  [ 75 205]
#  [ 75 190]
#  [ 73 195]]

# %% [markdown]
# #### Advanced Operations for your practice. The rest of your task is below these practice qs

# %% [markdown]
# 1. Construct an array from the list: [1,2,3]
# 2. Cast it into floats
# 3. Create an array of int ranging from 0-10
# 4. Create an array containing 7 evenly spaced numbers between 0 and 23
# 5. Create an array with shape (2,5,1,5,2,1) containing only the number 5
# 6. Eliminate all length-1 dimensions. See the function squeeze.
# 7. Reshape the resulting array from shape (2,5,3,2) to only 2D
# 8. Calculate the mean, std, var, max, min, of an array with shape (3,3,12,3) containing floats drawn
# from a normal distribution with mean 21 and sigma 4.5. see the np.random.normal.
# 9. Do the same but not on all elements but only on the 2nd dimension.
# 10. Transform the array such that it is only 1d. See the function Flatten or ravel
# 11. Remove all values smaller 15 and larger 26.
# 12. Clip all values smaller 15 and larger 26 to NaN. See the function Clip
# 13. Calculate the sum of the resulting array. It should not be NaN!.
# 14. Convert the NaN’s to 0.0. See Where
# 15. Save the array and load it again.

# %% [markdown]
# # Task restarts here again
# ### Using Matplotlib to chart data

# %%
# Draw three different charts using the below data

import matplotlib.pyplot as plt

# creating dataset
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
fruits = list(data.keys())
quantities = list(data.values())

# Bar Chart
plt.bar(fruits, quantities, color=['red', 'orange', 'yellow', 'green'])
plt.xlabel("Fruits")
plt.ylabel("Quantity")
plt.title("Bar Chart")
plt.show()

# Pie Chart
plt.pie(quantities, labels=fruits, autopct='%1.1f%%', colors=['red', 'orange', 'yellow', 'green'])
plt.title("Pie Chart")
plt.show()

# Line Chart
plt.plot(fruits, quantities, marker='o', linestyle='-', color='blue')
plt.xlabel("Fruits")
plt.ylabel("Quantity")
plt.title("Line Chart")
plt.grid(True)
plt.show()

# %% [markdown]
# # Lambda Functions Questions

# %% [markdown]
# Sorting with Keys
#
# - Sort the list of dictionaries people = [{'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 25}] by age using a lambda function.
# - Sort the list ['python', 'java', 'c', 'ruby'] in descending order of string length using a lambda function.

# %%
#code

people = [{'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 25}]
print(sorted(people, key=lambda n: n['age']))


languages = ['python', 'java', 'c', 'ruby']
print(sorted(languages, key=lambda n: len(n), reverse=True))
# Out:
# [{'name': 'Bob', 'age': 25}, {'name': 'Alice', 'age': 30}]
# ['python', 'java', 'ruby', 'c']

# %% [markdown]
# Filtering
#
# - Use filter with a lambda function to extract words longer than 3 characters from the list ["hi", "hello", "world", "ok"].
# - Write a lambda function to filter out all strings that start with the letter a from ['apple', 'banana', 'apricot', 'grape'].

# %%
#code
words=["hi", "hello", "world", "ok"]
print(list(filter(lambda n: len(n) > 3, words)))

fruits=['apple', 'banana', 'apricot', 'grape']
print(list(filter(lambda n: n[0] == 'a', fruits)))
# Out:
# ['hello', 'world']
# ['apple', 'apricot']

# %% [markdown]
# Implement a query function that takes a list of dictionaries and a lambda condition, and returns all dictionaries matching the condition.
# Example:
# `data = [{'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 25}], {'name': 'Anna', 'age': 22}`
#
# `result = query(data, lambda d: d['age'] > 26)`
#
# `print(result)  # Output: [{'name': 'Alice', 'age': 30}]`
#
# You will need to make sure that your function does the following
#
# 1. Filter by age
# 2. Filter names starting with 'A'
# 3. Filter based on name length

# %%
def query(data, condition):
    return [d for d in data if condition(d)]

data = [{'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 25}, {'name': 'Anna', 'age': 22}]

result_age = query(data, lambda d: d['age'] > 26)
print(result_age)  

# Filter names starting with 'A'
result_name_A = query(data, lambda d: d['name'].startswith('A'))
print(result_name_A) 


result_name_length = query(data, lambda d: len(d['name']) > 3)
print(result_name_length)
# Out:
# [{'name': 'Alice', 'age': 30}]
# [{'name': 'Alice', 'age': 30}, {'name': 'Anna', 'age': 22}]
# [{'name': 'Alice', 'age': 30}, {'name': 'Anna', 'age': 22}]
